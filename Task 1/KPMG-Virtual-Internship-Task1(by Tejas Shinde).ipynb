# %% [markdown]
# # KPMG Virtual Internship (Data Analytics)
#
# ## Task-1: Data Quality Assessment
#
# ### Client provided 3 datasets to prepare for analysis.

# %%
import pandas as pd

# %%
dt = pd.ExcelFile("KPMG-rawdt.xlsx")

# %%
Trans = pd.read_excel(dt, 'Transactions')
NewCustomerList = pd.read_excel(dt, 'NewCustomerList')
CustomerDemographic = pd.read_excel(dt, 'CustomerDemographic')
CustomerAddress = pd.read_excel(dt, 'CustomerAddress')

# %%
Trans.head(10)
# Out:
#    transaction_id  product_id  customer_id transaction_date  online_order  \
# 0               1           2         2950       2017-02-25           0.0
# 1               2           3         3120       2017-05-21           1.0
# 2               3          37          402       2017-10-16           0.0
# 3               4          88         3135       2017-08-31           0.0
# 4               5          78          787       2017-10-01           1.0
# 5               6          25         2339       2017-03-08           1.0
# 6               7          22         1542       2017-04-21           1.0
# 7               8          15         2459       2017-07-15           0.0
# 8               9          67         1305       2017-08-10           0.0
# 9              10          12         3262       2017-08-30           1.0
#
#   order_status           brand product_line product_class product_size  ...  \
# 0     Approved           Solex     Standard        medium       medium  ...
# ...

# %%
Trans.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20000 entries, 0 to 19999
# Data columns (total 26 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   transaction_id           20000 non-null  int64
#  1   product_id               20000 non-null  int64
#  2   customer_id              20000 non-null  int64
#  3   transaction_date         20000 non-null  datetime64[ns]
#  4   online_order             19640 non-null  float64
#  5   order_status             20000 non-null  object
#  6   brand                    19803 non-null  object
#  7   product_line             19803 non-null  object
#  8   product_class            19803 non-null  object
#  9   product_size             19803 non-null  object
#  10  list_price               20000 non-null  float64
#  11  standard_cost            19803 non-null  float64
#  12  product_first_sold_date  19803 non-null  float64
# ...

# %%
Transactions = Trans.iloc[:, 0:13]
Transactions.head()
# Out:
#    transaction_id  product_id  customer_id transaction_date  online_order  \
# 0               1           2         2950       2017-02-25           0.0
# 1               2           3         3120       2017-05-21           1.0
# 2               3          37          402       2017-10-16           0.0
# 3               4          88         3135       2017-08-31           0.0
# 4               5          78          787       2017-10-01           1.0
#
#   order_status           brand product_line product_class product_size  \
# 0     Approved           Solex     Standard        medium       medium
# 1     Approved   Trek Bicycles     Standard        medium        large
# 2     Approved      OHM Cycles     Standard           low       medium
# 3     Approved  Norco Bicycles     Standard        medium       medium
# 4     Approved  Giant Bicycles     Standard        medium        large
#
#    list_price  standard_cost  product_first_sold_date
# ...

# %%
Transactions.shape
# Out:
# (20000, 13)

# %%
Transactions.isnull().sum()
# Out:
# transaction_id               0
# product_id                   0
# customer_id                  0
# transaction_date             0
# online_order               360
# order_status                 0
# brand                      197
# product_line               197
# product_class              197
# product_size               197
# list_price                   0
# standard_cost              197
# product_first_sold_date    197
# dtype: int64

# %%
print(Transactions.columns)
print(Transactions.nunique())
# Out:
# Index(['transaction_id', 'product_id', 'customer_id', 'transaction_date',
#        'online_order', 'order_status', 'brand', 'product_line',
#        'product_class', 'product_size', 'list_price', 'standard_cost',
#        'product_first_sold_date'],
#       dtype='object')
# transaction_id             20000
# product_id                   101
# customer_id                 3494
# transaction_date             364
# online_order                   2
# order_status                   2
# brand                          6
# product_line                   4
# product_class                  3
# product_size                   3
# list_price                   296
# standard_cost                103
# product_first_sold_date      100
# dtype: int64

# %%
Transactions['order_status'].value_counts()
# Out:
# Approved     19821
# Cancelled      179
# Name: order_status, dtype: int64

# %%
Transactions['brand'].value_counts()
# Out:
# Solex             4253
# Giant Bicycles    3312
# WeareA2B          3295
# OHM Cycles        3043
# Trek Bicycles     2990
# Norco Bicycles    2910
# Name: brand, dtype: int64

# %%
Transactions['product_size'].value_counts()
# Out:
# medium    12990
# large      3976
# small      2837
# Name: product_size, dtype: int64

# %%
Transactions['product_first_sold_date'] = pd.to_datetime(Transactions['product_first_sold_date'], unit='s')
Transactions['product_first_sold_date'].head()
# Out:
# 0   1970-01-01 11:27:25
# 1   1970-01-01 11:35:01
# 2   1970-01-01 10:06:01
# 3   1970-01-01 10:02:25
# 4   1970-01-01 11:43:46
# Name: product_first_sold_date, dtype: datetime64[ns]

# %% [markdown]
# ###### product_first_sold_date column shows every transactions happened in same day.

# %%
NewCustomerList.head(10)
# Out:
#   first_name  last_name  gender  past_3_years_bike_related_purchases  \
# 0    Chickie    Brister    Male                                   86
# 1      Morly     Genery    Male                                   69
# 2    Ardelis  Forrester  Female                                   10
# 3     Lucine      Stutt  Female                                   64
# 4    Melinda     Hadlee  Female                                   34
# 5      Druci    Brandli  Female                                   39
# 6   Rutledge      Hallt    Male                                   23
# 7     Nancie       Vian  Female                                   74
# 8       Duff  Karlowicz    Male                                   50
# 9    Barthel     Docket    Male                                   72
#
#          DOB                     job_title job_industry_category  \
# 0 1957-07-12               General Manager         Manufacturing
# 1 1970-03-22           Structural Engineer              Property
# ...

# %%
NewCustomerList.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 23 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   first_name                           1000 non-null   object
#  1   last_name                            971 non-null    object
#  2   gender                               1000 non-null   object
#  3   past_3_years_bike_related_purchases  1000 non-null   int64
#  4   DOB                                  983 non-null    datetime64[ns]
#  5   job_title                            894 non-null    object
#  6   job_industry_category                835 non-null    object
#  7   wealth_segment                       1000 non-null   object
#  8   deceased_indicator                   1000 non-null   object
#  9   owns_car                             1000 non-null   object
#  10  tenure                               1000 non-null   int64
# ...

# %%
NewCustomerList.drop(['Column1', 'Column2', 'Column3',
       'Column4', 'Column5'], axis=1, inplace=True)

NewCustomerList.shape
# Out:
# (1000, 18)

# %%
NewCustomerList.isnull().sum()
# Out:
# first_name                               0
# last_name                               29
# gender                                   0
# past_3_years_bike_related_purchases      0
# DOB                                     17
# job_title                              106
# job_industry_category                  165
# wealth_segment                           0
# deceased_indicator                       0
# owns_car                                 0
# tenure                                   0
# address                                  0
# postcode                                 0
# state                                    0
# country                                  0
# property_valuation                       0
# Rank                                     0
# Value                                    0
# dtype: int64

# %%
NewCustomerList['gender'].value_counts()
# Out:
# Female    513
# Male      470
# U          17
# Name: gender, dtype: int64

# %%
NewCustomerList[NewCustomerList.gender == "U"]
# Out:
#     first_name    last_name gender  past_3_years_bike_related_purchases DOB  \
# 59       Normy     Goodinge      U                                    5 NaT
# 226      Hatti     Carletti      U                                   35 NaT
# 324   Rozamond       Turtle      U                                   69 NaT
# 358      Tamas      Swatman      U                                   65 NaT
# 360      Tracy   Andrejevic      U                                   71 NaT
# 374     Agneta      McAmish      U                                   66 NaT
# 434      Gregg      Aimeric      U                                   52 NaT
# 439      Johna       Bunker      U                                   93 NaT
# 574    Harlene         Nono      U                                   69 NaT
# 598   Gerianne       Kaysor      U                                   15 NaT
# 664     Chicky      Sinclar      U                                   43 NaT
# ...

# %% [markdown]
# ### There are 17 records of unspecified gender

# %%
NewCustomerList['DOB'].value_counts()
# Out:
# 1993-11-02    2
# 1994-04-15    2
# 1963-08-25    2
# 1995-08-13    2
# 1987-01-15    2
#              ..
# 1958-05-14    1
# 1977-12-08    1
# 1993-12-19    1
# 1954-10-06    1
# 1995-10-19    1
# Name: DOB, Length: 958, dtype: int64

# %%
NewCustomerList['job_industry_category'].value_counts()
# Out:
# Financial Services    203
# Manufacturing         199
# Health                152
# Retail                 78
# Property               64
# IT                     51
# Entertainment          37
# Argiculture            26
# Telecommunications     25
# Name: job_industry_category, dtype: int64

# %%
NewCustomerList['state'].value_counts()
# Out:
# NSW    506
# VIC    266
# QLD    228
# Name: state, dtype: int64

# %%
NewCustomerList['owns_car'].value_counts()
# Out:
# No     507
# Yes    493
# Name: owns_car, dtype: int64

# %%
CustomerDemographic.head()
# Out:
#    customer_id first_name last_name  gender  \
# 0           66     Anselm     Gawne    Male
# 1         1888      Sibyl   Scholtz  Female
# 2         3435    Stevena   Allcock  Female
# 3         2858  Benedicto     Radki    Male
# 4          422       Vito    Norker    Male
#
#    past_3_years_bike_related_purchases        DOB           job_title  \
# 0                                   46 2002-03-11   Account Executive
# 1                                   67 2002-01-26        Food Chemist
# 2                                   80 2002-01-15       Senior Editor
# 3                                    4 2002-01-09  Recruiting Manager
# 4                                   78 2002-01-06                 NaN
#
#   job_industry_category     wealth_segment deceased_indicator owns_car  tenure
# 0           Argiculture     High Net Worth                  N       No     1.0
# 1                Health      Mass Customer                  N      Yes     1.0
# ...

# %%
CustomerDemographic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3999 entries, 0 to 3998
# Data columns (total 12 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   customer_id                          3999 non-null   int64
#  1   first_name                           3999 non-null   object
#  2   last_name                            3874 non-null   object
#  3   gender                               3999 non-null   object
#  4   past_3_years_bike_related_purchases  3999 non-null   int64
#  5   DOB                                  3912 non-null   datetime64[ns]
#  6   job_title                            3493 non-null   object
#  7   job_industry_category                3343 non-null   object
#  8   wealth_segment                       3999 non-null   object
#  9   deceased_indicator                   3999 non-null   object
#  10  owns_car                             3999 non-null   object
# ...

# %%
CustomerDemographic.isnull().sum()
# Out:
# customer_id                              0
# first_name                               0
# last_name                              125
# gender                                   0
# past_3_years_bike_related_purchases      0
# DOB                                     87
# job_title                              506
# job_industry_category                  656
# wealth_segment                           0
# deceased_indicator                       0
# owns_car                                 0
# tenure                                  87
# dtype: int64

# %%
CustomerDemographic['gender'].value_counts()
# Out:
# Female    2037
# Male      1872
# U           87
# F            1
# M            1
# Femal        1
# Name: gender, dtype: int64

# %% [markdown]
# Some had a typing error

# %%
CustomerDemographic['gender'] = CustomerDemographic['gender'].replace('F','Female').replace('M','Male').replace('Femal','Female')

# %%
CustomerDemographic['gender'].value_counts()
# Out:
# Female    2039
# Male      1873
# U           87
# Name: gender, dtype: int64

# %%
CustomerDemographic['DOB'].value_counts()
# Out:
# 1978-01-30    7
# 1964-07-08    4
# 1978-08-19    4
# 1976-07-16    4
# 1976-09-25    4
#              ..
# 1955-03-06    1
# 1966-08-05    1
# 1968-11-16    1
# 1973-06-11    1
# 1958-08-02    1
# Name: DOB, Length: 3447, dtype: int64

# %%
CustomerDemographic['job_title'].value_counts()
# Out:
# Business Systems Development Analyst    45
# Tax Accountant                          44
# Social Worker                           44
# Internal Auditor                        42
# Recruiting Manager                      41
#                                         ..
# Human Resources Assistant IV             4
# Health Coach I                           3
# Research Assistant III                   3
# Health Coach III                         3
# Developer I                              1
# Name: job_title, Length: 195, dtype: int64

# %%
CustomerDemographic['job_industry_category'].value_counts()
# Out:
# Manufacturing         799
# Financial Services    774
# Health                602
# Retail                358
# Property              267
# IT                    222
# Entertainment         136
# Argiculture           113
# Telecommunications     72
# Name: job_industry_category, dtype: int64

# %%
CustomerDemographic['owns_car'].value_counts()
# Out:
# Yes    2024
# No     1975
# Name: owns_car, dtype: int64

# %%
CustomerDemographic['tenure'].value_counts()
# Out:
# 7.0     235
# 5.0     228
# 11.0    221
# 10.0    218
# 16.0    215
# 8.0     211
# 18.0    208
# 12.0    202
# 14.0    200
# 9.0     200
# 6.0     192
# 4.0     191
# 13.0    191
# 17.0    182
# 15.0    179
# 1.0     166
# 3.0     160
# 19.0    159
# 2.0     150
# 20.0     95
# 22.0     55
# 21.0     54
# Name: tenure, dtype: int64

# %%
CustomerAddress.head()
# Out:
#    customer_id              address  postcode            state    country  \
# 0            1   060 Morning Avenue      2016  New South Wales  Australia
# 1            2  6 Meadow Vale Court      2153  New South Wales  Australia
# 2            4   0 Holy Cross Court      4211              QLD  Australia
# 3            5  17979 Del Mar Point      2448  New South Wales  Australia
# 4            6     9 Oakridge Court      3216              VIC  Australia
#
#    property_valuation
# 0                  10
# 1                  10
# 2                   9
# 3                   4
# 4                   9

# %%
CustomerAddress.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3999 entries, 0 to 3998
# Data columns (total 6 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   customer_id         3999 non-null   int64
#  1   address             3999 non-null   object
#  2   postcode            3999 non-null   int64
#  3   state               3999 non-null   object
#  4   country             3999 non-null   object
#  5   property_valuation  3999 non-null   int64
# dtypes: int64(3), object(3)
# memory usage: 187.6+ KB

# %%
CustomerAddress.isnull().sum()
# Out:
# customer_id           0
# address               0
# postcode              0
# state                 0
# country               0
# property_valuation    0
# dtype: int64

# %%
CustomerAddress['state'].value_counts()
# Out:
# NSW                2054
# VIC                 939
# QLD                 838
# New South Wales      86
# Victoria             82
# Name: state, dtype: int64

# %%
CustomerAddress['country'].value_counts()
# Out:
# Australia    3999
# Name: country, dtype: int64

# %%
CustomerAddress['property_valuation'].value_counts()
# Out:
# 9     647
# 8     646
# 10    577
# 7     493
# 11    281
# 6     238
# 5     225
# 4     214
# 12    195
# 3     186
# 1     154
# 2     143
# Name: property_valuation, dtype: int64
